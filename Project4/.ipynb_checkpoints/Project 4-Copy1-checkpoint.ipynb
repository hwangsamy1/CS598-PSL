# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
rating_matrix = pd.read_csv("I-w9Wo-HSzmUGNNHw0pCzg_bc290b0e6b3a45c19f62b1b82b1699f1_Rmat.csv", index_col=0)

# %% [markdown]
# # System I: Recommendation Based on Popularity

# %%
def recommend_popular(rating_matrix, top_n=10):
    # Calculate popularity (e.g., average rating * number of ratings)
    movie_popularity = rating_matrix.apply(lambda col: col.mean(skipna=True) * col.notna().sum(), axis=0)
    top_movies = movie_popularity.sort_values(ascending=False).head(top_n)
    return top_movies.index.tolist(), top_movies.values

# %%
# Normalize rows by subtracting the mean
def normalize_matrix(matrix):
    row_means = matrix.mean(axis=1, skipna=True)
    return matrix.sub(row_means, axis=0)

# %%
# Compute the cosine similarity matrix
# def compute_cosine_similarity(matrix):
#     similarity = np.zeros((matrix.shape[1], matrix.shape[1]))
#     for i in range(matrix.shape[1]):
#         for j in range(matrix.shape[1]):
#             users_rated_both = (~matrix.iloc[:, i].isna()) & (~matrix.iloc[:, j].isna())
#             if users_rated_both.sum() > 2:  # At least 3 users must rate both
#                 ratings_i = matrix.iloc[:, i][users_rated_both]
#                 ratings_j = matrix.iloc[:, j][users_rated_both]
#                 dot_product = np.dot(ratings_i, ratings_j)
#                 norm_i = np.sqrt(np.dot(ratings_i, ratings_i))
#                 norm_j = np.sqrt(np.dot(ratings_j, ratings_j))
#                 if norm_i > 0 and norm_j > 0:
#                     cosine_similarity = dot_product / (norm_i * norm_j)
#                     similarity[i, j] = (1 + cosine_similarity) / 2
#                 else:
#                     similarity[i, j] = np.nan
#     return pd.DataFrame(similarity, index=matrix.columns, columns=matrix.columns)

from sklearn.metrics.pairwise import cosine_similarity

def compute_cosine_similarity_optimized(matrix):
    # Transpose the matrix to compute similarities between columns (movies)
    movie_features = matrix.fillna(0).to_numpy().T
    # Use sklearn's cosine_similarity
    cosine_sim = cosine_similarity(movie_features)
    # Transform similarity to (1 + cos) / 2
    similarity = (1 + cosine_sim) / 2
    # Mask similarities for less than 3 users rating both movies
    user_counts = (~matrix.isna()).T.dot(~matrix.isna())
    similarity[user_counts < 3] = np.nan
    return pd.DataFrame(similarity, index=matrix.columns, columns=matrix.columns)

# %% [markdown]
# # System II: IBCF-based Recommendations

# %%
def myIBCF(new_user_ratings, similarity_matrix, rating_matrix):
    predictions = {}
    for movie in similarity_matrix.index:
        if pd.isna(new_user_ratings[movie]):
            related_movies = similarity_matrix.loc[movie].dropna()
            rated_movies = new_user_ratings[~new_user_ratings.isna()]
            relevant_movies = related_movies.index.intersection(rated_movies.index)
            if relevant_movies.any():
                weights = related_movies.loc[relevant_movies]
                ratings = rated_movies.loc[relevant_movies]
                prediction = (weights * ratings).sum() / weights.sum()
                predictions[movie] = prediction
    # Sort by predicted ratings
    sorted_predictions = sorted(predictions.items(), key=lambda x: x[1], reverse=True)
    return [movie for movie, _ in sorted_predictions[:10]]

# %% [markdown]
# # Test the implementation

# %%
# Test the implementation with user u1181
if __name__ == "__main__":
    # Popularity-based recommendations
    top_movies, scores = recommend_popular(rating_matrix)
    print("Top 10 Popular Movies:", top_movies)

    # Normalize matrix and compute similarity
    normalized_matrix = normalize_matrix(rating_matrix)
    similarity_matrix = compute_cosine_similarity(normalized_matrix)

    # User "u1181" input from the rating matrix
    user_ratings_u1181 = rating_matrix.loc["u1181"]

    # IBCF-based recommendations for u1181
    ibcf_recommendations_u1181 = myIBCF(user_ratings_u1181, similarity_matrix, rating_matrix)
    print("Top 10 IBCF Recommendations for u1181:", ibcf_recommendations_u1181)

    # Hypothetical user input
    user_ratings_hypothetical = pd.Series(index=rating_matrix.columns, dtype="float")
    user_ratings_hypothetical["m1613"] = 5
    user_ratings_hypothetical["m1755"] = 4

    # IBCF-based recommendations for hypothetical user
    ibcf_recommendations_hypothetical = myIBCF(user_ratings_hypothetical, similarity_matrix, rating_matrix)
    print("Top 10 IBCF Recommendations for hypothetical user:", ibcf_recommendations_hypothetical)
# Out:
# Top 10 Popular Movies: ['m2858', 'm260', 'm1196', 'm1210', 'm2028', 'm1198', 'm593', 'm2571', 'm2762', 'm589']
# C:\Users\kaner\AppData\Local\Temp\ipykernel_47452\3301033086.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   prediction = (weights * ratings).sum() / weights.sum()
# Top 10 IBCF Recommendations for u1181: ['m1039', 'm3303', 'm1534', 'm3003', 'm106', 'm1002', 'm2839', 'm1026', 'm2843', 'm1058']
# C:\Users\kaner\AppData\Local\Temp\ipykernel_47452\3301033086.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   prediction = (weights * ratings).sum() / weights.sum()
# Top 10 IBCF Recommendations for hypothetical user: ['m1000', 'm1002', 'm1004', 'm1005', 'm1008', 'm1011', 'm1015', 'm1016', 'm1018', 'm1007']

# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

def compute_similarity_matrix(rating_matrix):
    # Fill missing values with 0 for cosine similarity calculation
    filled_matrix = rating_matrix.fillna(0)
    # Compute cosine similarity
    similarity = cosine_similarity(filled_matrix.T)
    # Convert to DataFrame
    similarity_df = pd.DataFrame(similarity, index=rating_matrix.columns, columns=rating_matrix.columns)
    return similarity_df

# Load the rating matrix
rating_matrix = pd.read_csv("I-w9Wo-HSzmUGNNHw0pCzg_bc290b0e6b3a45c19f62b1b82b1699f1_Rmat.csv", index_col=0)

# Compute similarity matrix
similarity_matrix = compute_similarity_matrix(rating_matrix)

# Save to CSV
similarity_matrix.to_csv("similarity_matrix.csv")

# %%
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Load Data
@st.cache_data
def load_data():
    # Load the rating matrix and similarity matrix
    rating_matrix = pd.read_csv("I-w9Wo-HSzmUGNNHw0pCzg_bc290b0e6b3a45c19f62b1b82b1699f1_Rmat.csv", index_col=0)
    similarity_matrix = pd.read_csv("similarity_matrix.csv", index_col=0)
    return rating_matrix, similarity_matrix

# Normalize matrix
def normalize_matrix(matrix):
    row_means = matrix.mean(axis=1, skipna=True)
    return matrix.sub(row_means, axis=0)

# Recommendation function
def myIBCF(new_user_ratings, similarity_matrix):
    predictions = {}
    for movie in similarity_matrix.index:
        if pd.isna(new_user_ratings.get(movie, np.nan)):  # Only predict for unrated movies
            similar_movies = similarity_matrix[movie].dropna()
            rated_movies = new_user_ratings.dropna()
            relevant_movies = rated_movies.index.intersection(similar_movies.index)

            if len(relevant_movies) > 0:
                weights = similar_movies[relevant_movies]
                ratings = rated_movies[relevant_movies]
                denominator = weights.sum()
                numerator = (weights * ratings).sum()

                if denominator > 0:
                    predictions[movie] = numerator / denominator
    sorted_predictions = sorted(predictions.items(), key=lambda x: x[1], reverse=True)
    return [movie for movie, _ in sorted_predictions[:10]]

# Main App
def main():
    st.title("Movie Recommender System")
    st.subheader("Rate Movies to Get Personalized Recommendations")

    # Load data
    rating_matrix, similarity_matrix = load_data()

    # Show sample movies to rate
    sample_movies = rating_matrix.columns[:100]
    st.write("Please rate the following sample movies (1-5 stars or leave blank):")
    user_ratings = {}
    for movie in sample_movies:
        user_ratings[movie] = st.slider(f"{movie}", min_value=1, max_value=5, value=None, step=1, format="%d")

    # Convert user ratings to a Pandas Series
    user_ratings_series = pd.Series(user_ratings).dropna()

    # Show recommendations if ratings are provided
    if st.button("Get Recommendations"):
        if user_ratings_series.empty:
            st.warning("Please rate at least one movie to get recommendations.")
        else:
            recommendations = myIBCF(user_ratings_series, similarity_matrix)
            st.success("Top 10 Recommended Movies for You:")
            for movie in recommendations:
                st.write(movie)

if __name__ == "__main__":
    main()
# Out:
# 2024-12-10 22:03:38.495 No runtime found, using MemoryCacheStorageManager
# 2024-12-10 22:03:38.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:38.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:38.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:38.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:38.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:38.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:38.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:39.017 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:39.019 Thread 'Thread-6': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.053 Session state does not function when running a script without `streamlit run`
# 2024-12-10 22:03:43.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-10 22:03:43